# %%
# 라이브러리 임포트
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 시각화를 위한 폰트 설정
plt.rc('font', family='AppleGothic')
plt.rc('axes', unicode_minus=False)

# %matplotlib inline

# %%
# 데이터 준비
df = pd.read_csv("https://raw.githubusercontent.com/corazzon/boostcourse-ds-510/master/data/medical_201909.csv.zip", low_memory=False)
df.shape
# Out:
# (91335, 39)

# %% [markdown]
# ### 📌 Q1. 전국 시도별 약국수를 구해주세요!
# - 상권업종소분류명이 약국인 것을 찾아 빈도수를 구해주세요. 이 때, value_counts, groupby, pivot_table 등 다양한 집계 방법을 통해 구해볼 수 있습니다. 각자 구하기 편한 방법을 통해 빈도수를 구합니다.
# - 다음의 결과가 나오도록 구합니다.

# %% [markdown]
# ### ✅ Q1 문제풀이)
# ```
# df_drug = df[df['상권업종소분류명'] == '약국']
# df_drug['시도명'].value_counts()
# ```

# %%
df_drug = df[df['상권업종소분류명'] == '약국']
df_drug['시도명'].value_counts()
# Out:
# 경기도        4510
# 서울특별시      3579
# 부산광역시      1130
# 경상남도       1017
# 인천광역시      1002
# 경상북도        915
# 대구광역시       870
# 전라북도        862
# 충청남도        830
# 전라남도        811
# 강원도         729
# 광주광역시       691
# 충청북도        648
# 대전광역시       603
# 울산광역시       362
# 제주특별자치도     226
# 세종특별자치시      99
# Name: 시도명, dtype: int64

# %% [markdown]
# ### 📌 Q2. 여러분은 반려동물과 관련된 사업을 하는 스타트업에 취업을 하여 상권분석을 해달라는 요청을 받았습니다. 병원이나 약국은 인구나 유동인구가 많은 지역에 주로 위치하고 있습니다. 그렇다면 동물병원도 병원이나 약국이 많은 곳에 더 많이 있을까요?
# - 빈도수를 구하고 시각화 하여 동물병원이 어느 지역에 많은지 분석해 주세요!
# - 다음의 결과가 나오도록 구합니다.

# %% [markdown]
# ### ✅ Q2 문제풀이)
# ```
# df_vet = df[df['상권업종소분류명'] == '동물병원']
#
# # 판다스로 bar chart 그리기
# df_vet['시도명'].value_counts().plot.barh()
#
# # seaborn으로 barchart 그릭
# x = pd.DataFrame(df_vet['시도명'].value_counts()).reset_index()
# x.columns = ['시도명', '동뭉병원의 수']
#
# sns.barplot(x=x['동뭉병원의 수'], y=x['시도명'])
# ```

# %%
df_vet = df[df['상권업종소분류명'] == '동물병원']
df_vet['시도명'].value_counts()
# Out:
# 경기도        992
# 서울특별시      557
# 인천광역시      193
# 경상북도       165
# 경상남도       161
# 부산광역시      153
# 충청남도       131
# 대구광역시      119
# 전라북도       111
# 강원도         85
# 대전광역시       77
# 전라남도        77
# 충청북도        75
# 광주광역시       71
# 울산광역시       61
# 제주특별자치도     46
# 세종특별자치시     13
# Name: 시도명, dtype: int64

# %% [markdown]
# #### 1) 판다스로 bar chart 그리기

# %%
# barchart 만들기
df_vet['시도명'].value_counts().plot.barh()
# Out:
# <AxesSubplot: >

# %% [markdown]
# #### 2) seaborn을 활용하여 barchart 그리기

# %%
x = pd.DataFrame(df_vet['시도명'].value_counts()).reset_index()
x.columns = ['시도명', '동뭉병원의 수']

sns.barplot(x=x['동뭉병원의 수'], y=x['시도명'])
# Out:
# <AxesSubplot: xlabel='동뭉병원의 수', ylabel='시도명'>

# %% [markdown]
# ### 📌Q3. 강남지역에는 다른 지역에 비해 피부과나 성형외과가 많아 보입니다. 실제로 해당 지역에 피부과나 성형외과가 다른 지역에 비해 전체 병원 수 중에서 어느 정도의 비율을 차지하고 있는지 알아보겠습니다.
# - 서울에 소재한 병원 중 상권업종소분류명에 "피부" 나 "성형"이 들어간 분류명을 찾아 구해주세요!
# - 피부과 성형외과 수 / 전체병원 수 로 비율을 구해주세요!
# - 비율이 높은 순서대로 정렬되게 구해주세요!
# - 수업에서 사용한 같은 CSV 파일을 사용하며 다음의 결과가 나오도록 구합니다.
# - 소숫점 두 번째짜리까지 출력하는 방법은 pandas round 로 검색해서 사용법을 알아보세요!

# %% [markdown]
# ### Q3 문제풀이)
# ```
# # 시도명이 서울인 데이터만 뽑기
# df_seoul = df[df['시도명'] == '서울특별시']
#
# # 상권업종소분류명에 "피부"나 "성형"이 들어간 병원 분류하기
# df_seoul_cos = df_seoul[(df_seoul['상권업종소분류명'].str.contains('피부')) | (df_seoul['상권업종소분류명'].str.contains('성형'))]
#
# # 상호명에 "피부"나 "성형"이 들어가지 않는 병원을 제거하기
# drop_rows = df_seoul_cos[~df_seoul_cos['상호명'].str.contains("피부|성형")]['상호명'].index.tolist()
# df_seoul_cos = df_seoul_cos.drop(drop_rows, axis=0)
#
# # 피부, 성형외과 수 / 전체 병원 수로 비율을 구하기
# df_seoul_hospital = df_seoul[df_seoul['상권업종중분류명'] == '병원']
# drop_rows2 = df_seoul_hospital[df_seoul_hospital['상호명'].str.contains("꽃배달|의료기|장례식장|상담소|어린이집")].index.tolist()
#
# df_seoul_hospital = df_seoul_hospital.drop(drop_rows2, axis=0)
#
# df_ratio = (df_seoul_cos['시군구명'].value_counts() / df_seoul_hospital['시군구명'].value_counts()).round(2).sort_values(ascending=False)
# df_ratio
#
# ```

# %%
# 시도명이 서울인 데이터만 뽑기
df_seoul = df[df['시도명'] == '서울특별시']
df_seoul.head(2)
# Out:
#      상가업소번호       상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명 상권업종소분류코드  \
# 1  20024149  타워광명내과의원  NaN         S       의료       S01       병원    S01B07
# 8  20808534    코원성형외과  NaN         S       의료       S01       병원    S01B08
#
#   상권업종소분류명 표준산업분류코드  ...                     건물관리번호   건물명  \
# 1    내과/외과   Q86201  ...  1168011800104670014000001   NaN
# 8  정형/성형외과   Q86201  ...  1168010700105920004010990  이가빌딩
#
#                  도로명주소     구우편번호   신우편번호  동정보 층정보  호정보          경도         위도
# 1  서울특별시 강남구 언주로30길 39  135270.0  6292.0  NaN   4  NaN  127.053198  37.488742
# 8    서울특별시 강남구 논현로 826  135893.0  6025.0  NaN   4  NaN  127.028531  37.522223
#
# [2 rows x 39 columns]

# %%
# 상권업종소분류명에 "피부"나 "성형"이 들어간 병원 분류하기
df_seoul_cos = df_seoul[(df_seoul['상권업종소분류명'].str.contains('피부')) | (df_seoul['상권업종소분류명'].str.contains('성형'))]
df_seoul_cos.shape
# Out:
# (1373, 39)

# %%
# 상호명에 "피부"나 "성형"이 들어가지 않는 병원을 제거하기
drop_rows = df_seoul_cos[~df_seoul_cos['상호명'].str.contains("피부|성형")]['상호명'].index.tolist()

df_seoul_cos = df_seoul_cos.drop(drop_rows, axis=0)

# %%
df_seoul_cos.shape
# Out:
# (878, 39)

# %%
# 전체 병원 수 구하기 
df_seoul_hospital = df_seoul[df_seoul['상권업종중분류명'] == '병원']
drop_rows2 = df_seoul_hospital[df_seoul_hospital['상호명'].str.contains("꽃배달|의료기|장례식장|상담소|어린이집")].index.tolist()

print(df_seoul_hospital.shape)
df_seoul_hospital = df_seoul_hospital.drop(drop_rows2, axis=0)
print(df_seoul_hospital.shape)
# Out:
# (13406, 39)
# (13389, 39)

# %%
df_ratio = (df_seoul_cos['시군구명'].value_counts() / df_seoul_hospital['시군구명'].value_counts()).round(2).sort_values(ascending=False)
df_ratio
# Out:
# 강남구     0.19
# 서초구     0.11
# 강동구     0.05
# 중구      0.04
# 송파구     0.04
# 성북구     0.04
# 서대문구    0.04
# 마포구     0.04
# 노원구     0.03
# 은평구     0.03
# 광진구     0.03
# 성동구     0.03
# 영등포구    0.03
# 양천구     0.02
# 강북구     0.02
# 종로구     0.02
# 용산구     0.02
# 관악구     0.02
# 강서구     0.02
# 구로구     0.02
# 동작구     0.02
# 동대문구    0.02
# 중랑구     0.02
# 도봉구     0.01
# 금천구     0.01
# Name: 시군구명, dtype: float64

# %% [markdown]
# ### 📌Q4. 평균 기대수명이 점점 길어지면서 실버 의료 산업도 주목받고 있습니다. 여러분은 실버 의료 산업과 관련된 스타트업에 취업했습니다. 지도를 시각화하여 '노인/치매병원'이 주로 어디에 위치하고 있는지를 찾아보고자 합니다.
# - folium 을 통해 지도에 전국의 '노인/치매병원'을 표시해 주세요!
# - 다음과 같이 시각화 하며, folium 의 문서를 참고하여 다른 기능을 사용하여 좀 더 멋지게 지도를 꾸며도 좋습니다.
# - folium 문서 : https://python-visualization.github.io/folium/quickstart.html

# %%
df_sliver_care = df[df['상권업종소분류명'] == '노인/치매병원']
df_sliver_care.shape
# Out:
# (1055, 39)

# %%
import folium

map = folium.Map(location=[df_sliver_care['위도'].mean(), df_sliver_care['경도'].mean()], zoom_start=7)

# %%
for i in df_sliver_care.index:
    name = df_sliver_care['상호명'][i]
    address = df_sliver_care['도로명주소'][i]
    popup = f"상호명: {name}, 도로명주소: {address}"
    location = [df_sliver_care['위도'][i], df_sliver_care['경도'][i]]

    folium.Marker(location=location, popup=popup).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a0da8c9456b579fcc9548eeefdf9c0b8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a0da8c9456b579fcc9548eeefdf9c0b8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a0da8c9456b579fcc9548eeefdf9c0b8 = L.map(
#                 &quot;map_a0da8c9456b579fcc9548eeefdf9c0b8&quot;,
#                 {
#                     center: [36.322638410225366, 127.69216156637984],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4de02cb31e9314562fc58160c1f49ff1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a0da8c9456b579fcc9548eeefdf9c0b8);
#
#
#             var marker_2d13b7e94a5569ceae9fb5086964d391 = L.marker(
#                 [35.2091539574761, 129.040772964856],
#                 {}
#             ).addTo(map_a0da8c9456b579fcc9548eeefdf9c0b8);
#
#
#         var popup_afd8fa532da3d9c20827d3d73daff33c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e33539a88bcba36202edecf8be14827b = $(`&lt;div id=&quot;html_e33539a88bcba36202edecf8be14827b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;상호명: 다사랑요양병원, 도로명주소: 부산광역시 북구 덕천로 339&lt;/div&gt;`)[0];
#                 popup_afd8fa532da3d9c20827d3d73daff33c.setContent(html_e33539a88bcba36202edecf8be14827b);
#
#
#
#         marker_2d13b7e94a5569ceae9fb5086964d391.bindPopup(popup_afd8fa532da3d9c20827d3d73daff33c)
#         ;
#
#
#
#
#             var marker_c3026c10e6ef0d00132c08213c5b1ef0 = L.marker(
#                 [34.9865848568725, 127.746980976467],
#                 {}
#             ).addTo(map_a0da8c9456b579fcc9548eeefdf9c0b8);
#
#
#         var popup_06856f02d69aeec878501071f59850d5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4b7d64d64dbd4c2c76a6b08fbd626894 = $(`&lt;div id=&quot;html_4b7d64d64dbd4c2c76a6b08fbd626894&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;상호명: 노경회, 도로명주소: 전라남도 광양시 진월면 용소길 7&lt;/div&gt;`)[0];
#                 popup_06856f02d69aeec878501071f59850d5.setContent(html_4b7d64d64dbd4c2c76a6b08fbd626894);
#
#
#
#         marker_c3026c10e6ef0d00132c08213c5b1ef0.bindPopup(popup_06856f02d69aeec878501071f59850d5)
#         ;
#
#
#
#
#             var marker_6d5720c6dc585282e541012bb965601e = L.marker(
#                 [37.6936890859817, 126.780121523366],
#                 {}
#             ).addTo(map_a0da8c9456b579fcc9548eeefdf9c0b8);
#
#
#         var popup_0fd95eecf181a569ea2df303fd6ffb0b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0d3a00da1d22e7d7ccc083b90ad626d3 = $(`&lt;div id=&quot;html_0d3a00da1d22e7d7ccc083b90ad626d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;상호명: 일산카네이션너싱홈, 도로명주소: 경기도 고양시 일산동구 중산로 241&lt;/div&gt;`)[0];
#                 popup_0fd95eecf181a569ea2df303fd6ffb0b.setContent(html_0d3a00da1d22e7d7ccc083b90ad626d3);
#
#
#
#         marker_6d5720c6dc585282e541012bb965601e.bindPopup(popup_0fd95eecf181a569ea2df303fd6ffb0b)
#         ;
#
#
#
#
#             var marker_f6a8272730bdb4819f9c232ae728ef46 = L.marker(
#                 [34.9910140897983, 127.460606294325],
#                 {}
#             ).addTo(map_a0da8c9456b579fcc9548eeefdf9c0b8);
#
#
#         var popup_84532d7a2c15e41ed4acb15e9f1918c1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_58d39d4db5f6d708c9804452686cd962 = $(`&lt;div id=&quot;html_58d39d4db5f6d708c9804452686cd962&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;상호명: 은성복지회, 도로명주소: 전라남도 순천시 조비길 298&lt;/div&gt;`)[0];
#                 popup_84532d7a2c15e41ed4acb15e9f1918c1.setContent(html_58d39d4db5f6d708c9804452686cd962);
#
#
#
#         marker_f6a8272730bdb4819f9c232ae728ef46.bindPopup(popup_84532d7a2c15e41ed4acb15e9f1918c1)
#         ;
#
#
#
#
#             var marker_40c4837efd09e599f667657bb384aa06 = L.marker(
#                 [36.3651320905281, 128.295523973833],
#                 {}
#             ).addTo(map_a0da8c9456b579fcc9548eeefdf9c0b8);
#
#
#         var popup_4631dbf884fc6262751743d0944fb3b8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_66b5154ec5b74c78ecdeea925bbfc38a = $(`&lt;div id=&quot;html_66b5154ec5b74c78ecdeea925bbfc38a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;상호명: 하은실버홈, 도로명주소: 경상북도 상주시 낙동면 영남제일로 125-17&lt;/div&gt;`)[0];
#                 popup_4631dbf884fc6262751743d0944fb3b8.setContent(html_66b5154ec5b74c78ecdeea925bbfc38a);
#
#
#
#         marker_40c4837efd09e599f6676

# %%
import folium
from folium import Marker
from folium.plugins import MarkerCluster

map = folium.Map(location=[df_sliver_care['위도'].mean(), df_sliver_care['경도'].mean()], zoom_start=7)

# %%
mc = MarkerCluster()

for i in df_sliver_care.index:
    name = df_sliver_care['상호명'][i]
    address = df_sliver_care['도로명주소'][i]
    popup = f"상호명: {name}, 도로명주소: {address}"
    location = [df_sliver_care['위도'][i], df_sliver_care['경도'][i]]

    mc.add_child(Marker(location=location, popup=popup))

mc.add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_614fa60c9996a27a8c79235c96eda4bc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_614fa60c9996a27a8c79235c96eda4bc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_614fa60c9996a27a8c79235c96eda4bc = L.map(
#                 &quot;map_614fa60c9996a27a8c79235c96eda4bc&quot;,
#                 {
#                     center: [36.322638410225366, 127.69216156637984],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b232031ef465e9f33f8080b641c003ed = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_614fa60c9996a27a8c79235c96eda4bc);
#
#
#             var marker_cluster_8b2d810d4ab7bfdbc733698b8020e997 = L.markerClusterGroup(
#                 {}
#             );
#             map_614fa60c9996a27a8c79235c96eda4bc.addLayer(marker_cluster_8b2d810d4ab7bfdbc733698b8020e997);
#
#
#             var marker_a13a7f167e540a60c923f2a5e40b259c = L.marker(
#                 [35.2091539574761, 129.040772964856],
#                 {}
#             ).addTo(marker_cluster_8b2d810d4ab7bfdbc733698b8020e997);
#
#
#         var popup_f85bf3110f2f7ac010add1b6241e8d6b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bce5e1b4b73d02b84625b6e9b649a9d3 = $(`&lt;div id=&quot;html_bce5e1b4b73d02b84625b6e9b649a9d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;상호명: 다사랑요양병원, 도로명주소: 부산광역시 북구 덕천로 339&lt;/div&gt;`)[0];
#                 popup_f85bf3110f2f7ac010add1b6241e8d6b.setContent(html_bce5e1b4b73d02b84625b6e9b649a9d3);
#
#
#
#         marker_a13a7f167e540a60c923f2a5e40b259c.bindPopup(popup_f85bf3110f2f7ac010add1b6241e8d6b)
#         ;
#
#
#
#
#             var marker_0ffda3e0e9e96e1f3d913e3ea268faa8 = L.marker(
#                 [34.9865848568725, 127.746980976467],
#                 {}
#             ).addTo(marker_cluster_8b2d810d4ab7bfdbc733698b8020e997);
#
#
#         var popup_faac020d95208d891a7f48cef3b74847 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8bd9e782a09b8b8ddc2c2346476bb5dc = $(`&lt;div id=&quot;html_8bd9e782a09b8b8ddc2c2346476bb5dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;상호명: 노경회, 도로명주소: 전라남도 광양시 진월면 용소길 7&lt;/div&gt;`)[0];
#                 popup_faac020d95208d891a7f48cef3b74847.setContent(html_8bd9e782a09b8b8ddc2c2346476bb5dc);
#
#
#
#         marker_0ffda3e0e9e96e1f3d913e3ea268faa8.bindPopup(popup_faac020d95208d891a7f48cef3b74847)
#         ;
#
#
#
#
#             var marker_e74c4c1743791205496d55968b667dcd = L.marker(
#                 [37.6936890859817, 126.780121523366],
#                 {}
#             ).addTo(marker_cluster_8b2d810d4ab7bfdbc733698b8020e997);
#
#
#         var popup_fa5a8cd2143d98e8d7ca56852da70226 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_12f2bb5c1993db09a4cc633b528abe72 = $(`&lt;div id=&quot;html_12f2bb5c1993db09a4cc633b528abe72&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;상호명: 일산카네이션너싱홈, 도로명주소: 경기도 고양시 일산동구 중산로 241&lt;/div&gt;`)[0];
#                 popup_fa5a8cd2143d98e8d7ca56852da70226.setContent(html_12f2bb5c1993db09a4cc633b528abe72);
#
#
#
#         marker_e74c4c1743791205496d55968b667dcd.bindPopup(popup_fa5a8cd2143d98e8d7ca56852da70226)
#         ;
#
#
#
#
#             var marker_2d770dff77cb0eeed5a543a25e53ac69 = L.marker(
#                 [34.9910140897983, 127.460606294325],
#                 {}
#             ).addTo(marker_cluster_8b2d810d4ab7bfdbc733698b8020e997);
#
#
#         var popup_8edc5f6476c3b3df1f8b1efda5f535e0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1547bd63146d81e11f21962b5efd6d68 = $(`&lt;div id=&quot;html_1547bd63146d81e11f21962b5efd6d68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;상호명: 은성복지회, 도로명주소: 전라남도 순천시 조비길 298&lt;/div&gt;`)[0];
#                 popup_8edc5f6476c3b3df1f8b1efda5f535e0.setContent(html_1547bd63146d81e11f21962b5efd6d68);
#
#
#
#         marker_2d770dff77cb0eeed5a543a25e53ac69.bindPopup(popup_8edc5f6476c3b3df1f8b1efda5f535e0)
#         ;
#
#
#
#
#             v
